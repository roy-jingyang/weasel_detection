# %% [markdown]
# # Split a log into "train" and "test" sets
# This is used when a reference model is missing.
#
# The "train" set will be used to discover a model, which will then be used as an
# artificial reference model to test the detection methods.
#
# Splitting will be applied to cases.

# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
log_name = 'bpic15'

fn_logs = {
    'bpic15': './data/preproc/bpic15.csv',
    'bpic17': './data/preproc/bpic2017.csv',
    'propr': './data/preproc/proprietary.csv'
}

# %%
log = pd.read_csv(fn_logs[log_name])
log
# Out:
#          case_id                                       activity  resource  \
# 0        4284682          enter senddate procedure confirmation    560852
# 1        4511735               register submission date request   1254625
# 2        3090877          enter senddate procedure confirmation   3148844
# 3        5726442                 enter senddate acknowledgement   2013365
# 4        3871304                        date for inspection MER    560532
# ...          ...                                            ...       ...
# 262623  10069611             date draft decision for inspection    560752
# 262624  12663845  start decision phase decision permitting sent    560912
# 262625  12999831  start decision phase decision permitting sent    560872
# 262626  12999831   enter senddate decision environmental permit    560872
# 262627   3256221               register submission date request    560462
#
#        complete timestamp  (case) IDofConceptCase (case) Includes_subCases  \
# 0         18/11/2009 9:00                     NaN                        J
# 1         23/11/2009 9:00                     NaN                        J
# 2           1/1/2010 9:00                     NaN                        J
# 3          13/5/2010 8:00               5726449.0                        N
# 4          29/6/2010 8:00                     NaN                        N
# ...                   ...                     ...                      ...
# 262623      5/3/2015 9:00              10069618.0                      NaN
# 262624      5/3/2015 9:00              12663987.0                      NaN
# 262625      9/3/2015 9:00              13000092.0                      NaN
# 262626      9/3/2015 9:00              13000092.0                      NaN
# 262627      1/8/2015 8:00                     NaN                        J
#
#         (case) Responsible_actor  (case) SUMleges (case) caseProcedure  \
# 0                       560852.0       1438.34350                  NaN
# 1                       560604.0        258.80100                  NaN
# 2                      3442724.0              NaN           Uitgebreid
# 3                      2013365.0      23847.62700           Uitgebreid
# 4                       560458.0              NaN           Uitgebreid
# ...                          ...              ...                  ...
# 262623                  560431.0              NaN           Uitgebreid
# 262624                  560912.0       5019.30600                  NaN
# 262625                  560872.0        220.82385                  NaN
# 262626                  560872.0        220.82385                  NaN
# 262627                  560462.0              NaN           Uitgebreid
#
#        (case) caseStatus  ...  (case) landRegisterID  \
# 0                      G  ...                    NaN
# 1                      G  ...              4504496.0
# 2                      G  ...                    NaN
# 3                      G  ...              5726441.0
# 4                      G  ...                    NaN
# ...                  ...  ...                    ...
# 262623                 O  ...                    NaN
# 262624                 O  ...             12663844.0
# 262625                 O  ...               717776.0
# 262626                 O  ...               717776.0
# 262627                 T  ...                    NaN
#
#                 (case) last_phase  \
# 0                 Besluit genomen
# 1       Vergunning onherroepelijk
# 2             Vergunning verleend
# 3          Ontwerpbesluit genomen
# 4            Procedure afgebroken
# ...                           ...
# 262623     Ontwerpbesluit genomen
# 262624      Beschikking verzonden
# 262625      Beschikking verzonden
# 262626      Beschikking verzonden
# 262627         Aanvraag ontvangen
#
#                                              (case) parts  \
# 0                                              Bouw,Sloop
# 1                        Brandveilig gebruik (vergunning)
# 2                                     Milieu (vergunning)
# 3                                                    Bouw
# 4                                     Milieu (vergunning)
# ...                                                   ...
# 262623  Milieu (omgevingsvergunning beperkte milieutoe...
# 262624                                               Bouw
# 262625                                                Kap
# 262626                                                Kap
# 262627  Bouw,Kap,Milieu (neutraal wijziging),Flora en ...
#
#        (case) requestComplete         Activity  \
# 0                        True   01_HOOFD_190_2
# 1                        True     01_HOOFD_010
# 2                        True   01_HOOFD_065_2
# 3                       False   08_AWB45_051_2
# 4                        True     01_HOOFD_080
# ...                       ...              ...
# 262623                  False       10_UOV_030
# 262624                  False  01_HOOFD_510_2a
# 262625                   True  01_HOOFD_510_2a
# 262626                   True   01_HOOFD_510_2
# 262627                   True     01_HOOFD_010
#
#                                            activityNameNL  \
# 0              invoeren verzenddatum procedurebevestiging
# 1                  registratie datum binnenkomst aanvraag
# 2              invoeren verzenddatum procedurebevestiging
# 3              invoeren verzenddatum ontvangstbevestiging
# 4                                    datum ter inzage MER
# ...                                                   ...
# 262623                datum ontwerpbeschikking ter inzage
# 262624  instellen besluitfase:besluit vergunnen verzonden
# 262625  instellen besluitfase:besluit vergunnen verzonden
# 262626  invoeren verzenddatum beschikking omgevingsver...
# 262627             registratie datum binnenkomst aanvraag
#
#        lifecycle:transition monitoringResource        question municipality
# 0                  complete             560852           EMPTY       muni-4
# 1                  complete            1254625           EMPTY       muni-5
# 2                  complete             560922           EMPTY       muni-3
# 3                  complete            2013365           EMPTY       muni-3
# 4                  complete             560458  29/6/2010 0:00       muni-2
# ...                     ...                ...             ...          ...
# 262623             complete             560431           EMPTY       muni-4
# 262624             complete            2670601           EMPTY       muni-1
# 262625             complete             560872           EMPTY       muni-1
# 262626             complete             560872           EMPTY       muni-1
# 262627             complete             560462           EMPTY       muni-1
#
# [262628 rows x 21 columns]

# %% [markdown]
# ## Split based on time
#
# The train set will contain X% cases that happened first, the remaining (100 -
# X)% of cases will constitute the test set.
#
# NB: This method assumes no concept dript happening in the process.

# %%
if log_name in {'propr'}:
    log['_start timestamp'] = pd.to_datetime(log['start timestamp'], format='mixed', dayfirst=True)
if log_name in {'bpic15', 'propr'}:
    log['_complete timestamp'] = pd.to_datetime(log['complete timestamp'], format='mixed', dayfirst=True)

df_case_time = list()
if log_name == 'bpic15':
    for case_id, trace in log.groupby('case_id'):
        df_case_time.append({
            'case_id': case_id,
            'case_start': trace['_complete timestamp'].min(),
            'case_end': trace['_complete timestamp'].max()
        })
if log_name == 'propr':
    for case_id, trace in log.groupby('case_id'):
        df_case_time.append({
            'case_id': case_id,
            'case_start': trace['_start timestamp'].min(),
            'case_end': trace['_complete timestamp'].max()
        })
df_case_time = pd.DataFrame(df_case_time)
df_case_time['case_duration_minutes'] = (
    df_case_time['case_end'] - df_case_time['case_start']
).dt.total_seconds() / 60
df_case_time
# Out:
#        case_id          case_start            case_end  case_duration_minutes
# 0      2742737 2011-06-01 08:00:00 2011-06-16 20:17:00                22337.0
# 1      2760925 2010-10-05 08:00:00 2010-10-07 22:57:00                 3777.0
# 2      2771451 2010-10-06 08:00:00 2010-12-15 09:00:00               100860.0
# 3      2782209 2010-10-06 08:00:00 2010-11-24 09:00:00                70620.0
# 4      2783345 2010-10-07 08:00:00 2010-12-15 09:00:00                99420.0
# ...        ...                 ...                 ...                    ...
# 5642  24129041 2015-02-13 09:00:00 2015-02-20 18:59:00                10679.0
# 5643  24129720 2015-02-16 09:00:00 2015-02-20 20:18:00                 6438.0
# 5644  24130200 2015-02-16 09:00:00 2015-02-20 20:17:00                 6437.0
# 5645  24153462 2015-02-19 09:00:00 2015-02-23 23:49:00                 6649.0
# 5646  24154137 2015-02-19 09:00:00 2015-02-24 00:17:00                 6677.0
#
# [5647 rows x 4 columns]

# %%
df_case_time = df_case_time.sort_values(by='case_start')

num_train = int(len(df_case_time) * 0.7)
case_id_train = df_case_time.iloc[:(num_train+1)]['case_id']
case_id_test = df_case_time.iloc[(num_train+1):]['case_id']

print(log.loc[log['case_id'].isin(case_id_train), 'case_id'].nunique())
print(log.loc[log['case_id'].isin(case_id_test), 'case_id'].nunique())

fnout_train = f'{log_name}_train-70.csv'
fnout_test = f'{log_name}_test-30.csv'
log.loc[log['case_id'].isin(case_id_train)].to_csv(
    fnout_train, index=False
)
log.loc[log['case_id'].isin(case_id_test)].to_csv(
    fnout_test, index=False
)
# Out:
# 3953
# 1694
